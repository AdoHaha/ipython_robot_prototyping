# %%
from IPython.display import Image
from IPython.display import YouTubeVideo


##run these slides using ipython nbconvert intro_presentation.ipynb --to slides --post serve

# %% [markdown]
# While some of us are still installing and setting up, I will make a shor presentation about Robotics and ROS
#
#
# # Rapid robot prototyping using ROS and Ipython
#
# by [Igor](https://twitter.com/IgorZub), [Lidka](https://twitter.com/lidkalee) & Marcin

# %% [markdown]
# # Our robotics projects
#
# [roboterapia.eu](http://roboterapia.eu/) is our project for supporting therapists of autism with robotic technologies.
#
# [funbots.eu](http://funbots.eu) is our little startup project for robots for entertainment and deep learning
#
# [gentle.pl](http://gentle.pl) is Igor's blog about robotics
#
# [Robotics @ Politechnika Lodzka](http://robotyka.p.lodz.pl/)

# %% [markdown]
# ### Roboterapia
# ![](images/autism.jpg)
#
# [roboterapia.eu](http://roboterapia.eu/) is our project for supporting therapists of autism with robotic technologies.

# %% [markdown]
# ### Robotics @ Politechnika Lodzka

# %%
YouTubeVideo("LfRwhA2H9fw")

# %%
YouTubeVideo("9W649FWe0iw")

# %% [markdown]
# # What are robots?
#
#  - Moving, intelligent (able do decide in a limited way) devices
#  - Sometimes human-like (humanoids, androids), sometimes not.
#  - Capable of something different that humans (working faster, longer hours, more precise, working in difficult environment)
#  - Less capable in many ways: intelligence, socialability, energy efficiency ...

# %%
YouTubeVideo("X028Z945rZg")

# %%
YouTubeVideo("yzEakQTZIIg")

# %%
YouTubeVideo("0fkDVNkFr40")

# %%
print("millitary robots ;(")
YouTubeVideo("rVlhMGQgDkY")
# Out:
# millitary robots

# %% [markdown]
# # What is ROS?
#
# ![](images/ros_equation.png)
#  - pipes
#  - tools
#  - knowledge
#  - community

# %% [markdown]
# ## The whole idea behind ROS is to simplify prototyping so you could do more with a smaller team
#
# ![](images/giants.jpg)

# %% [markdown]
# ### Prototyping robots
#
# Prototyping is producing a system that enables you to test your ideas.
# You want to create enough functionality to gather new **knowledge** that will guide your design. You don't want a "mini product" or a "crappy product", just to have enough to understand your issue better.
#
# ![](images/prototyping.jpg)

# %% [markdown]
# We will use Jupyter notebook in our robot prototyping because it enables us to rapidly create understandable program-chunks, visualize the incoming data and create simple control interfaces

# %% [markdown]
# ### Let's start the workshop
#
# Our plan:
#
#  - Introduction to ROS communication tools:
#   - Connecting to ROS
#   - ROS Topic
#   - ROS Service
#   - ROS Param
#  - Prototyping robot controls (via Ipython widgets)
#  - Visualizing incoming data using widgets and Bokeh
#  - __Trying your knowledge on ESP bots__
#  - Tour of some other ROS tools: rviz, rosbag, tf
#  - Wrapup
